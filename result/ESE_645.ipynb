# %%
# Mount drive and create output directory
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip3 install torchmetrics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 926.4/926.4 kB 14.5 MB/s eta 0:00:00
# ...

# %%
# Test the paths
from config import *
print(f"Input data path: {BASE_PATH}")
print(f"Output path: {OUTPUT_BASE_DIR}")
print(f"Can read mapping file: {os.path.exists(MAPPING_FILE)}")
print(f"Can read source images: {os.path.exists(SOURCE_IMAGES_DIR)}")
print(f"Can write to output: {os.access(OUTPUT_BASE_DIR, os.W_OK)}")
# Out:
# Input data path: /content/drive/MyDrive/PIE-Bench_v1
# Output path: /content/drive/MyDrive/ESE_645_result_sd_ddim_default
# Can read mapping file: True
# Can read source images: True
# Can write to output: True

# %%
device = "cuda"

# %%
# !python generate_edits.py --category "1_change_object_80" --all_subfolders
# Out:
# Streaming output truncated to the last 5000 lines.
#  21% 21/99 [00:09<00:35,  2.19it/s]
#  22% 22/99 [00:10<00:35,  2.19it/s]
#  23% 23/99 [00:10<00:34,  2.19it/s]
#  24% 24/99 [00:10<00:34,  2.20it/s]
#  25% 25/99 [00:11<00:33,  2.19it/s]
#  26% 26/99 [00:11<00:33,  2.19it/s]
#  27% 27/99 [00:12<00:32,  2.19it/s]
#  28% 28/99 [00:12<00:32,  2.19it/s]
#  29% 29/99 [00:13<00:31,  2.19it/s]
#  30% 30/99 [00:13<00:31,  2.19it/s]
#  31% 31/99 [00:14<00:31,  2.19it/s]
#  32% 32/99 [00:14<00:30,  2.19it/s]
#  33% 33/99 [00:15<00:30,  2.19it/s]
#  34% 34/99 [00:15<00:29,  2.19it/s]
#  35% 35/99 [00:15<00:29,  2.19it/s]
#  36% 36/99 [00:16<00:28,  2.19it/s]
#  37% 37/99 [00:16<00:28,  2.20it/s]
#  38% 38/99 [00:17<00:27,  2.19it/s]
#  39% 39/99 [00:17<00:27,  2.19it/s]
#  40% 40/99 [00:18<00:26,  2.19it/s]
#  41% 41/99 [00:18<00:26,  2.19it/s]
#  42% 42/99 [00:19<00:25,  2.19it/s]
#  43% 43/99 [00:19<00:25,  2.19it/s]
#  44% 44/99 [00:20<00:25,  2.20it/s]
# ...

# %%
# !python evaluate.py \
    --category "1_change_object_80" \
    --source_dir "/content/drive/MyDrive/PIE-Bench_v1/annotation_images" \
    --generated_dir "/content/drive/MyDrive/ESE_645_result_sd_ddim_default/generated_images" \
    --output_dir "/content/drive/MyDrive/ESE_645_result_sd_ddim_default/evaluation_results/1_change_object_80"
# Out:
# Using paths:
# Source directory: /content/drive/MyDrive/PIE-Bench_v1/annotation_images
# Generated images: /content/drive/MyDrive/ESE_645_result_sd_ddim_default/generated_images
# Output directory: /content/drive/MyDrive/ESE_645_result_sd_ddim_default/evaluation_results/1_change_object_80
# 2024-11-29 01:40:22.217320: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-29 01:40:22.236685: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-29 01:40:22.242729: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python generate_edits.py --category "2_add_object_80" --all_subfolders
# Out:
# Streaming output truncated to the last 5000 lines.
#  97% 96/99 [00:43<00:01,  2.20it/s]
#  98% 97/99 [00:44<00:00,  2.20it/s]
# 100% 99/99 [00:44<00:00,  2.22it/s]
#
#   0% 0/70 [00:00<?, ?it/s]
#   1% 1/70 [00:00<00:31,  2.20it/s]
#   3% 2/70 [00:00<00:30,  2.21it/s]
#   4% 3/70 [00:01<00:30,  2.20it/s]
#   6% 4/70 [00:01<00:29,  2.20it/s]
#   7% 5/70 [00:02<00:29,  2.20it/s]
#   9% 6/70 [00:02<00:29,  2.20it/s]
#  10% 7/70 [00:03<00:28,  2.20it/s]
#  11% 8/70 [00:03<00:28,  2.19it/s]
#  13% 9/70 [00:04<00:27,  2.20it/s]
#  14% 10/70 [00:04<00:27,  2.19it/s]
#  16% 11/70 [00:05<00:26,  2.20it/s]
#  17% 12/70 [00:05<00:26,  2.20it/s]
#  19% 13/70 [00:05<00:25,  2.20it/s]
#  20% 14/70 [00:06<00:25,  2.20it/s]
#  21% 15/70 [00:06<00:25,  2.20it/s]
#  23% 16/70 [00:07<00:24,  2.19it/s]
#  24% 17/70 [00:07<00:24,  2.20it/s]
#  26% 18/70 [00:08<00:23,  2.20it/s]
#  27% 19/70 [00:08<00:23,  2.20it/s]
#  29% 20/70 [00:09<00:22,  2.19it/s]
#  30% 21/70 [00:09<00:22,  2.20it/s]
# ...

# %%
# !python evaluate.py \
    --category "2_add_object_80" \
    --source_dir "/content/drive/MyDrive/PIE-Bench_v1/annotation_images" \
    --generated_dir "/content/drive/MyDrive/ESE_645_result_sd_ddim_default/generated_images" \
    --output_dir "/content/drive/MyDrive/ESE_645_result_sd_ddim_default/evaluation_results/2_add_object_80"
# Out:
# Using paths:
# Source directory: /content/drive/MyDrive/PIE-Bench_v1/annotation_images
# Generated images: /content/drive/MyDrive/ESE_645_result_sd_ddim_default/generated_images
# Output directory: /content/drive/MyDrive/ESE_645_result_sd_ddim_default/evaluation_results/2_add_object_80
# 2024-11-29 01:42:59.424922: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-29 01:42:59.445695: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-29 01:42:59.451755: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python generate_edits.py --category "3_delete_object_80" --all_subfolders
# Out:
# Streaming output truncated to the last 5000 lines.
#  12% 12/99 [00:05<00:39,  2.20it/s]
#  13% 13/99 [00:05<00:38,  2.21it/s]
#  14% 14/99 [00:06<00:38,  2.20it/s]
#  15% 15/99 [00:06<00:38,  2.21it/s]
#  16% 16/99 [00:07<00:37,  2.20it/s]
#  17% 17/99 [00:07<00:37,  2.20it/s]
#  18% 18/99 [00:08<00:36,  2.21it/s]
#  19% 19/99 [00:08<00:36,  2.21it/s]
#  20% 20/99 [00:09<00:35,  2.21it/s]
#  21% 21/99 [00:09<00:35,  2.21it/s]
#  22% 22/99 [00:09<00:34,  2.20it/s]
#  23% 23/99 [00:10<00:34,  2.21it/s]
#  24% 24/99 [00:10<00:34,  2.20it/s]
#  25% 25/99 [00:11<00:33,  2.21it/s]
#  26% 26/99 [00:11<00:33,  2.20it/s]
#  27% 27/99 [00:12<00:32,  2.20it/s]
#  28% 28/99 [00:12<00:32,  2.20it/s]
#  29% 29/99 [00:13<00:31,  2.20it/s]
#  30% 30/99 [00:13<00:31,  2.20it/s]
#  31% 31/99 [00:14<00:30,  2.20it/s]
#  32% 32/99 [00:14<00:30,  2.20it/s]
#  33% 33/99 [00:14<00:29,  2.20it/s]
#  34% 34/99 [00:15<00:29,  2.20it/s]
#  35% 35/99 [00:15<00:29,  2.19it/s]
# ...

# %%
# !python evaluate.py \
    --category "3_delete_object_80" \
    --source_dir "/content/drive/MyDrive/PIE-Bench_v1/annotation_images" \
    --generated_dir "/content/drive/MyDrive/ESE_645_result_sd_ddim_default/generated_images" \
    --output_dir "/content/drive/MyDrive/ESE_645_result_sd_ddim_default/evaluation_results/3_delete_object_80"
# Out:
# Using paths:
# Source directory: /content/drive/MyDrive/PIE-Bench_v1/annotation_images
# Generated images: /content/drive/MyDrive/ESE_645_result_sd_ddim_default/generated_images
# Output directory: /content/drive/MyDrive/ESE_645_result_sd_ddim_default/evaluation_results/3_delete_object_80
# 2024-11-29 01:46:37.011263: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-29 01:46:37.030747: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-29 01:46:37.036747: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python generate_edits.py --category "4_change_attribute_content_40" --all_subfolders
# Out:
# Streaming output truncated to the last 5000 lines.
#  40% 40/99 [00:18<00:27,  2.18it/s]
#  41% 41/99 [00:18<00:26,  2.18it/s]
#  42% 42/99 [00:19<00:26,  2.18it/s]
#  43% 43/99 [00:19<00:25,  2.18it/s]
#  44% 44/99 [00:20<00:25,  2.18it/s]
#  45% 45/99 [00:20<00:24,  2.18it/s]
#  46% 46/99 [00:21<00:24,  2.18it/s]
#  47% 47/99 [00:21<00:23,  2.18it/s]
#  48% 48/99 [00:22<00:23,  2.18it/s]
#  49% 49/99 [00:22<00:22,  2.18it/s]
#  51% 50/99 [00:22<00:22,  2.18it/s]
#  52% 51/99 [00:23<00:22,  2.18it/s]
#  53% 52/99 [00:23<00:21,  2.18it/s]
#  54% 53/99 [00:24<00:21,  2.18it/s]
#  55% 54/99 [00:24<00:20,  2.18it/s]
#  56% 55/99 [00:25<00:20,  2.18it/s]
#  57% 56/99 [00:25<00:19,  2.19it/s]
#  58% 57/99 [00:26<00:19,  2.18it/s]
#  59% 58/99 [00:26<00:18,  2.19it/s]
#  60% 59/99 [00:27<00:18,  2.19it/s]
#  61% 60/99 [00:27<00:17,  2.19it/s]
#  62% 61/99 [00:27<00:17,  2.18it/s]
#  63% 62/99 [00:28<00:16,  2.18it/s]
#  64% 63/99 [00:28<00:16,  2.18it/s]
# ...

# %%
# !python evaluate.py \
    --category "4_change_attribute_content_40" \
    --source_dir "/content/drive/MyDrive/PIE-Bench_v1/annotation_images" \
    --generated_dir "/content/drive/MyDrive/ESE_645_result_sd_ddim_default/generated_images" \
    --output_dir "/content/drive/MyDrive/ESE_645_result_sd_ddim_default/evaluation_results/4_change_attribute_content_40"
# Out:
# Using paths:
# Source directory: /content/drive/MyDrive/PIE-Bench_v1/annotation_images
# Generated images: /content/drive/MyDrive/ESE_645_result_sd_ddim_default/generated_images
# Output directory: /content/drive/MyDrive/ESE_645_result_sd_ddim_default/evaluation_results/4_change_attribute_content_40
# 2024-11-27 04:09:59.943387: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-27 04:09:59.963389: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-27 04:09:59.969895: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python generate_edits.py --category "5_change_attribute_pose_40" --all_subfolders
# Out:
# 2024-11-27 05:07:23.496659: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-27 05:07:23.516805: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-27 05:07:23.522934: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-27 05:07:24.724786: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading pipeline components...: 100% 7/7 [00:00<00:00,  7.39it/s]
#
# Processing folder: 5_change_attribute_pose_40/1_artificial/1_animal
# Total images found: 5
# Selected 2/5 images from folder
#
# ...

# %%
# !python evaluate.py \
    --category "5_change_attribute_pose_40" \
    --source_dir "/content/drive/MyDrive/PIE-Bench_v1/annotation_images" \
    --generated_dir "/content/drive/MyDrive/ESE_645_result_sd_ddim_default/generated_images" \
    --output_dir "/content/drive/MyDrive/ESE_645_result_sd_ddim_default/evaluation_results/5_change_attribute_pose_40"
# Out:
# Using paths:
# Source directory: /content/drive/MyDrive/PIE-Bench_v1/annotation_images
# Generated images: /content/drive/MyDrive/ESE_645_result_sd_ddim_default/generated_images
# Output directory: /content/drive/MyDrive/ESE_645_result_sd_ddim_default/evaluation_results/5_change_attribute_pose_40
# 2024-11-27 05:08:53.145840: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-27 05:08:53.165244: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-27 05:08:53.171296: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python generate_edits.py --category "6_change_attribute_color_40" --all_subfolders
# Out:
# 2024-11-27 05:13:10.497267: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-27 05:13:10.517367: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-27 05:13:10.523358: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-27 05:13:11.753862: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading pipeline components...: 100% 7/7 [00:00<00:00,  7.48it/s]
#
# Processing folder: 6_change_attribute_color_40/1_artificial/1_animal
# Total images found: 5
# Selected 2/5 images from folder
#
# ...

# %%
# !python evaluate.py \
    --category "6_change_attribute_color_40" \
    --source_dir "/content/drive/MyDrive/PIE-Bench_v1/annotation_images" \
    --generated_dir "/content/drive/MyDrive/ESE_645_result_sd_ddim_default/generated_images" \
    --output_dir "/content/drive/MyDrive/ESE_645_result_sd_ddim_default/evaluation_results/6_change_attribute_color_40"
# Out:
# Using paths:
# Source directory: /content/drive/MyDrive/PIE-Bench_v1/annotation_images
# Generated images: /content/drive/MyDrive/ESE_645_result_sd_ddim_default/generated_images
# Output directory: /content/drive/MyDrive/ESE_645_result_sd_ddim_default/evaluation_results/6_change_attribute_color_40
# 2024-11-27 07:12:23.826244: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-27 07:12:23.845653: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-27 07:12:23.852018: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python generate_edits.py --category "7_change_attribute_material_40" --all_subfolders
# Out:
# Streaming output truncated to the last 5000 lines.
#  19% 13/70 [00:06<00:27,  2.08it/s]
#  20% 14/70 [00:06<00:26,  2.07it/s]
#  21% 15/70 [00:07<00:26,  2.08it/s]
#  23% 16/70 [00:07<00:25,  2.09it/s]
#  24% 17/70 [00:08<00:25,  2.08it/s]
#  26% 18/70 [00:08<00:25,  2.08it/s]
#  27% 19/70 [00:09<00:24,  2.08it/s]
#  29% 20/70 [00:09<00:23,  2.09it/s]
#  30% 21/70 [00:10<00:23,  2.08it/s]
#  31% 22/70 [00:10<00:23,  2.09it/s]
#  33% 23/70 [00:11<00:22,  2.09it/s]
#  34% 24/70 [00:11<00:22,  2.09it/s]
#  36% 25/70 [00:11<00:21,  2.09it/s]
#  37% 26/70 [00:12<00:21,  2.09it/s]
#  39% 27/70 [00:12<00:20,  2.09it/s]
#  40% 28/70 [00:13<00:20,  2.10it/s]
#  41% 29/70 [00:13<00:19,  2.09it/s]
#  43% 30/70 [00:14<00:19,  2.08it/s]
#  44% 31/70 [00:14<00:18,  2.09it/s]
#  46% 32/70 [00:15<00:18,  2.09it/s]
#  47% 33/70 [00:15<00:17,  2.08it/s]
#  49% 34/70 [00:16<00:17,  2.08it/s]
#  50% 35/70 [00:16<00:16,  2.07it/s]
#  51% 36/70 [00:17<00:16,  2.07it/s]
# ...

# %%
# !python evaluate.py \
    --category "7_change_attribute_material_40" \
    --source_dir "/content/drive/MyDrive/PIE-Bench_v1/annotation_images" \
    --generated_dir "/content/drive/MyDrive/ESE_645_result_sd_ddim_default/generated_images" \
    --output_dir "/content/drive/MyDrive/ESE_645_result_sd_ddim_default/evaluation_results/7_change_attribute_material_40"
# Out:
# Using paths:
# Source directory: /content/drive/MyDrive/PIE-Bench_v1/annotation_images
# Generated images: /content/drive/MyDrive/ESE_645_result_sd_ddim_default/generated_images
# Output directory: /content/drive/MyDrive/ESE_645_result_sd_ddim_default/evaluation_results/7_change_attribute_material_40
# 2024-11-29 01:48:08.605885: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-29 01:48:08.625731: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-29 01:48:08.631781: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python generate_edits.py --category "8_change_background_80" --all_subfolders
# Out:
# Streaming output truncated to the last 5000 lines.
#  12% 12/99 [00:05<00:41,  2.07it/s]
#  13% 13/99 [00:06<00:41,  2.07it/s]
#  14% 14/99 [00:06<00:41,  2.07it/s]
#  15% 15/99 [00:07<00:40,  2.07it/s]
#  16% 16/99 [00:07<00:40,  2.06it/s]
#  17% 17/99 [00:08<00:39,  2.06it/s]
#  18% 18/99 [00:08<00:39,  2.07it/s]
#  19% 19/99 [00:09<00:38,  2.08it/s]
#  20% 20/99 [00:09<00:38,  2.08it/s]
#  21% 21/99 [00:10<00:37,  2.07it/s]
#  22% 22/99 [00:10<00:37,  2.07it/s]
#  23% 23/99 [00:11<00:36,  2.07it/s]
#  24% 24/99 [00:11<00:36,  2.07it/s]
#  25% 25/99 [00:12<00:35,  2.07it/s]
#  26% 26/99 [00:12<00:35,  2.07it/s]
#  27% 27/99 [00:13<00:34,  2.07it/s]
#  28% 28/99 [00:13<00:34,  2.08it/s]
#  29% 29/99 [00:13<00:33,  2.08it/s]
#  30% 30/99 [00:14<00:33,  2.08it/s]
#  31% 31/99 [00:14<00:32,  2.07it/s]
#  32% 32/99 [00:15<00:32,  2.08it/s]
#  33% 33/99 [00:15<00:31,  2.09it/s]
#  34% 34/99 [00:16<00:31,  2.08it/s]
#  35% 35/99 [00:16<00:30,  2.07it/s]
# ...

# %%
# !python evaluate.py \
    --category "8_change_background_80" \
    --source_dir "/content/drive/MyDrive/PIE-Bench_v1/annotation_images" \
    --generated_dir "/content/drive/MyDrive/ESE_645_result_sd_ddim_default/generated_images" \
    --output_dir "/content/drive/MyDrive/ESE_645_result_sd_ddim_default/evaluation_results/8_change_background_80"
# Out:
# Using paths:
# Source directory: /content/drive/MyDrive/PIE-Bench_v1/annotation_images
# Generated images: /content/drive/MyDrive/ESE_645_result_sd_ddim_default/generated_images
# Output directory: /content/drive/MyDrive/ESE_645_result_sd_ddim_default/evaluation_results/8_change_background_80
# 2024-11-29 01:49:03.815511: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-29 01:49:03.834885: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-29 01:49:03.840819: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python generate_edits.py --category "9_change_style_80" --all_subfolders
# Out:
# Streaming output truncated to the last 5000 lines.
#  12% 12/99 [00:05<00:41,  2.12it/s]
#  13% 13/99 [00:06<00:40,  2.12it/s]
#  14% 14/99 [00:06<00:40,  2.12it/s]
#  15% 15/99 [00:07<00:39,  2.12it/s]
#  16% 16/99 [00:07<00:39,  2.12it/s]
#  17% 17/99 [00:08<00:38,  2.12it/s]
#  18% 18/99 [00:08<00:38,  2.12it/s]
#  19% 19/99 [00:08<00:37,  2.12it/s]
#  20% 20/99 [00:09<00:37,  2.11it/s]
#  21% 21/99 [00:09<00:36,  2.12it/s]
#  22% 22/99 [00:10<00:36,  2.11it/s]
#  23% 23/99 [00:10<00:35,  2.12it/s]
#  24% 24/99 [00:11<00:35,  2.12it/s]
#  25% 25/99 [00:11<00:34,  2.11it/s]
#  26% 26/99 [00:12<00:34,  2.12it/s]
#  27% 27/99 [00:12<00:33,  2.12it/s]
#  28% 28/99 [00:13<00:33,  2.12it/s]
#  29% 29/99 [00:13<00:33,  2.12it/s]
#  30% 30/99 [00:14<00:32,  2.12it/s]
#  31% 31/99 [00:14<00:32,  2.12it/s]
#  32% 32/99 [00:15<00:31,  2.12it/s]
#  33% 33/99 [00:15<00:31,  2.12it/s]
#  34% 34/99 [00:16<00:30,  2.12it/s]
#  35% 35/99 [00:16<00:30,  2.12it/s]
# ...

# %%
# !python evaluate.py \
    --category "9_change_style_80" \
    --source_dir "/content/drive/MyDrive/PIE-Bench_v1/annotation_images" \
    --generated_dir "/content/drive/MyDrive/ESE_645_result_sd_ddim_default/generated_images" \
    --output_dir "/content/drive/MyDrive/ESE_645_result_sd_ddim_default/evaluation_results/9_change_style_80"
# Out:
# Using paths:
# Source directory: /content/drive/MyDrive/PIE-Bench_v1/annotation_images
# Generated images: /content/drive/MyDrive/ESE_645_result_sd_ddim_default/generated_images
# Output directory: /content/drive/MyDrive/ESE_645_result_sd_ddim_default/evaluation_results/9_change_style_80
# 2024-11-29 01:50:43.018613: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-29 01:50:43.038417: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-29 01:50:43.044408: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
import pandas as pd

# %%
CATEGORIES = [
    "0_random_140",
    "1_change_object_80",
    "2_add_object_80",
    "3_delete_object_80",
    "4_change_attribute_content_40",
    "5_change_attribute_pose_40",
    "6_change_attribute_color_40",
    "7_change_attribute_material_40",
    "8_change_background_80",
    "9_change_style_80"
]

# %%
# Base path for the CSV files
base_path = "/content/drive/MyDrive/ESE_645_result_sd_ddim_default/evaluation_results/"

# Initialize an empty list to store DataFrames
dfs = []

# Iterate over each category to read and concatenate CSV files
for category in CATEGORIES:
    csv_path = f"{base_path}{category}/evaluation_results_{category}.csv"
    try:
        df = pd.read_csv(csv_path)
        dfs.append(df)
    except FileNotFoundError:
        print(f"File not found: {csv_path}")

# Concatenate all DataFrames into a single DataFrame
if dfs:
    combined_df = pd.concat(dfs, ignore_index=True)

    # Save the combined DataFrame to a new CSV file
    combined_df.to_csv("/content/drive/MyDrive/ESE_645_result_sd_ddim_default/evaluation_results/combined_evaluation_results.csv", index=False)
    print("CSV files concatenated successfully!")
else:
    print("No CSV files were found to concatenate.")
# Out:
# CSV files concatenated successfully!

# %%
combined_df.columns
# Out:
# Index(['file_id', 'psnr', 'lpips', 'mse', 'ssim',
#        'clip_similarity_source_image', 'clip_similarity_target_image',
#        'clip_similarity_target_image_edit_part', 'structure_distance'],
#       dtype='object')

# %%
combined_df.drop(["file_id"],axis = 1, inplace=True)

# %%
result = combined_df.mean()

# %%
result
# Out:
# psnr                                      21.272232
# lpips                                      0.173273
# mse                                        0.010022
# ssim                                       0.693654
# clip_similarity_source_image              26.138996
# clip_similarity_target_image              23.798908
# clip_similarity_target_image_edit_part    21.211902
# structure_distance                         0.020555
# dtype: float64

# %%
result.to_csv("/content/drive/MyDrive/ESE_645_result_sd_ddim_default/evaluation_results/combined_evaluation_results_mean.csv")
